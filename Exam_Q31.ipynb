# %% [markdown]
# <a href="https://colab.research.google.com/github/qmjacinto01/CPE018---CPE31S2/blob/main/Exam_Q31.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2

# %%
cv2.imread('/content/drive/MyDrive/exam/nature.jpg')
# Out:
# array([[[125, 147, 172],
#         [125, 149, 171],
#         [128, 154, 171],
#         ...,
#         [160, 119,   3],
#         [160, 119,   3],
#         [160, 119,   3]],
#
#        [[127, 149, 174],
#         [127, 151, 173],
#         [129, 155, 172],
#         ...,
#         [160, 120,   2],
#         [160, 120,   2],
#         [160, 120,   2]],
#
#        [[130, 153, 175],
#         [131, 155, 175],
#         [131, 157, 173],
#         ...,
#         [161, 121,   3],
#         [161, 121,   3],
#         [161, 121,   3]],
#
#        ...,
#
#        [[  0,   7,   0],
#         [ 15,   3,   0],
#         [ 45,  27,   4],
#         ...,
#         [ 47,  26,   4],
#         [ 46,  25,   3],
#         [ 45,  24,   3]],
#
#        [[ 13,  17,   6],
#         [ 70,  60,   0],
#         [106,  92,   3],
#         ...,
#         [ 51,  32,   5],
#         [ 50,  31,   4],
#         [ 49,  30,   3]],
#
#        [[ 28,   9,  18],
#         [108,  82,  12],
#         [117,  85,  10],
#         ...,
#         [ 54,  40,  12],
#         [ 52,  38,   9],
#         [ 49,  36,   4]]], dtype=uint8)

# %%
import cv2
import matplotlib.pyplot as plt

output_path = '/content/drive/MyDrive/exam/processed.jpg'

processed_image = cv2.imread(output_path)

plt.imshow(processed_image, cmap='gray')
plt.axis('off')
plt.show()

# %%
import cv2

grayscale_image = cv2.imread('/content/drive/MyDrive/exam/nature.jpg', cv2.IMREAD_GRAYSCALE)

if grayscale_image is None:
    print("Error: Could not load image. Please check the path.")
else:
    resized_image = cv2.resize(grayscale_image, (300, 300))

    output_path = '/content/drive/MyDrive/exam/processed.jpg'
    cv2.imwrite(output_path, resized_image)

    print(f"Image successfully converted to grayscale, resized to 300x300, and saved as {output_path}")
# Out:
# Image successfully converted to grayscale, resized to 300x300, and saved as /content/drive/MyDrive/exam/processed.jpg
